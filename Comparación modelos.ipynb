# %%
pip install -q transformers
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import pipeline
import pandas as pd

sentiment_pipeline = pipeline(model="finiteautomata/bertweet-base-sentiment-analysis")
# Out:
# C:\Users\USUARIO\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# emoji is not installed, thus not converting emoticons or emojis into text. Install emoji: pip3 install emoji==0.6.0

# %% [markdown]
# ### Read database

# %%
df = pd.read_excel('https://raw.githubusercontent.com/kmiloR2/Maestria/main/feedback-examples.xlsx')
df.head()
# Out:
#                                             Feedback     Label
# 0  I want to talk to you about your work on this ...  Negative
# 1  I want to talk to you about your priorities. I...  Positive
# 2  Reaching your goal of [name the goal] is a big...  Positive
# 3  One of your most impactful moments was how you...  Positive
# 4  It’s clear you’re excited about the project. B...  Negative

# %% [markdown]
# ### Modelo BERT

# %%
df["Sentiment_BERT"] = df["Feedback"].apply(lambda feedback: sentiment_pipeline(feedback))

# Extract the sentiment labels and scores from the model output
df["Sentiment_Label_BERT"] = df["Sentiment_BERT"].apply(lambda sentiment: sentiment[0]['label'])

# Crear un diccionario de mapeo de etiquetas
label_mapping = {
    "POS": "Positive",
    "NEG": "Negative",
    "NEU": "Neutral"
}

# Aplicar la función de mapeo y agregar la nueva columna "Label_BERT"
df["Label_BERT"] = df["Sentiment_Label_BERT"].apply(lambda label: label_mapping.get(label, label))

# Print the DataFrame with sentiment analysis results
df.head()
# Out:
#                                             Feedback     Label  \
# 0  I want to talk to you about your work on this ...  Negative
# 1  I want to talk to you about your priorities. I...  Positive
# 2  Reaching your goal of [name the goal] is a big...  Positive
# 3  One of your most impactful moments was how you...  Positive
# 4  It’s clear you’re excited about the project. B...  Negative
#
#                                     Sentiment_BERT Sentiment_Label_BERT  \
# 0  [{'label': 'NEU', 'score': 0.7832766175270081}]                  NEU
# 1  [{'label': 'POS', 'score': 0.8706808686256409}]                  POS
# 2  [{'label': 'POS', 'score': 0.9895287156105042}]                  POS
# 3   [{'label': 'POS', 'score': 0.990766167640686}]                  POS
# 4  [{'label': 'POS', 'score': 0.5218806266784668}]                  POS
#
#   Label_BERT
# 0    Neutral
# 1   Positive
# 2   Positive
# 3   Positive
# 4   Positive

# %% [markdown]
# ### Modelo Roberta

# %%
sentiment_pipeline = pipeline(model="cardiffnlp/twitter-roberta-base-sentiment")

# %%
df["Sentiment_ROBERTA"] = df["Feedback"].apply(lambda feedback: sentiment_pipeline(feedback))
df["Sentiment_Label_ROBERTA"] = df["Sentiment_ROBERTA"].apply(lambda sentiment: sentiment[0]['label'])
# Crear un diccionario de mapeo de etiquetas
label_mapping = {
    "LABEL_2": "Positive",
    "LABEL_0": "Negative",
    "LABEL_1": "Neutral"
}

# Aplicar la función de mapeo y agregar la nueva columna "Label_BERT"
df["Label_ROBERTA"] = df["Sentiment_Label_ROBERTA"].apply(lambda label: label_mapping.get(label, label))

# Print the DataFrame with sentiment analysis results
df.head()
# Out:
#                                             Feedback     Label  \
# 0  I want to talk to you about your work on this ...  Negative
# 1  I want to talk to you about your priorities. I...  Positive
# 2  Reaching your goal of [name the goal] is a big...  Positive
# 3  One of your most impactful moments was how you...  Positive
# 4  It’s clear you’re excited about the project. B...  Negative
#
#                                     Sentiment_BERT Sentiment_Label_BERT  \
# 0  [{'label': 'NEU', 'score': 0.7832766175270081}]                  NEU
# 1  [{'label': 'POS', 'score': 0.8706808686256409}]                  POS
# 2  [{'label': 'POS', 'score': 0.9895287156105042}]                  POS
# 3   [{'label': 'POS', 'score': 0.990766167640686}]                  POS
# 4  [{'label': 'POS', 'score': 0.5218806266784668}]                  POS
#
#   Label_BERT                                  Sentiment_ROBERTA  \
# 0    Neutral  [{'label': 'LABEL_1', 'score': 0.4449909329414...
# 1   Positive  [{'label': 'LABEL_2', 'score': 0.8078871369361...
# 2   Positive  [{'label': 'LABEL_2', 'score': 0.9781804084777...
# 3   Positive  [{'label': 'LABEL_2', 'score': 0.9867540001869...
# 4   Positive  [{'label': 'LABEL_2', 'score': 0.8090545535087...
#
#   Sentiment_Label_ROBERTA Label_ROBERTA
# 0                 LABEL_1       Neutral
# 1                 LABEL_2      Positive
# 2                 LABEL_2      Positive
# 3                 LABEL_2      Positive
# 4                 LABEL_2      Positive

# %% [markdown]
# ### Modelo AFINN
#
# This model works different versus the previous 2, this model is based on a predefined lexicon (dictionary), which means that asigns the label according to predefined value(postive or negative) assigned to each word. This means that would be necessary apply a cleainig on the database removing stops words that could intefere with the final result.

# %%
import re
import nltk
from nltk.corpus import stopwords
from tqdm import tqdm

def preprocess_text(text_data):
   
    punctuation = re.compile(r'[^\w\s]')
    
    english_stopwords = set(stopwords.words('english'))
  
    preprocessed_text = []
    for sentence in tqdm(text_data):
        # Converting lowercase
        sentence = sentence.lower()
        
        # Removing punctuations
        sentence = punctuation.sub('', sentence)
  
        # Removing stopwords and tokenizing
        preprocessed_text.append(' '.join(token for token in nltk.word_tokenize(sentence) if token not in english_stopwords))
  
    return preprocessed_text

# %%
#fill na

# preprocess text /remove stop words, punctuation, lower case
preprocessed_review = preprocess_text(df['Feedback'].values)
df['Feedback_2'] = preprocessed_review
df
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 53/53 [00:00<00:00, 1558.70it/s]
#                                              Feedback     Label  \
# 0   I want to talk to you about your work on this ...  Negative
# 1   I want to talk to you about your priorities. I...  Positive
# 2   Reaching your goal of [name the goal] is a big...  Positive
# 3   One of your most impactful moments was how you...  Positive
# 4   It’s clear you’re excited about the project. B...  Negative
# 5   I want to congratulate you, not only for your ...  Positive
# 6   I really appreciated how you kept me up to dat...  Positive
# 7   I’ve noticed that you seem less engaged lately...  Negative
# 8   “I’m curious about where we are with Y project...  Positive
# 9    know that [name the project] is really import...  Positive
# 10  I can’t help but notice that this is the third...  Negative
# 11  I sensed that there was tension in our plannin...  Positive
# 12  It’d be great to see you take on fewer project...  Positive
# 13  I’ve noticed that recently you take a long tim...  Negative
# 14  Your work on X, Y and Z were solid, valuable a...  Positive
# 15  I wanted to talk to you about what you said du...  Positive
# 16   I am truly impressed with how you have manage...  Positive
# 17  You know I’ve always appreciated your grasp of...  Negative
# 18  I’d love for you to keep that big-picture visi...  Positive
# 19  We’ve all been adapting to this new reality di...  Positive
# 20  Hey, I noticed you weren’t in our last few mor...  Negative
# 21  You did a fantastic job collaborating with you...  Positive
# 22  When I say you are an excellent point of conta...  Positive
# 23  It’d be great to see you tap into your resourc...  Positive
# 24  Your input to today's meeting was a game-chang...  Positive
# 25  I wanted to check in and see how things are go...  Negative
# 26  I’m glad we’re taking the time to check-in. I ...  Negative
# 27  I really appreciated your efforts to keep ever...  Positive
# 28  I appreciate your input. When you have an issu...  Positive
# 29  I appreciate the fact that you have been cover...  Positive
# 30  I know there are a lot of rumors flying around...  Positive
# 31  Hey, I wanted to check-in and see how you felt...  Negative
# 32  It is commendable that you acted as a mediator...  Positive
# 33  This morning you left our team meeting early. ...  Negative
# 34  I've noticed that you've been taking on increa...  Positive
# 35  Congratulations on finishing this challenging ...  Positive
# 36  I've seen you grow tremendously in the three y...  Positive
# 37  Helen, I always appreciate how productive and ...  Positive
# 38  We've seen incredible growth and progress sinc...  Positive
# 39  We received positive verbal feedback from one ...  Positive
# 40  Joe, you have impressive time management skill...  Positive
# 41  Sandra, your passion and talent for graphic de...  Positive
# 42  According to our client, you have been putting...  Positive
# 43  Thank you for all of the recent overtime you'v...  Positive
# 44  Bobby, I wanted to check in with you about beh...  Negative
# 45   admire the tact with which you handled the co...  Positive
# 46  Jade, I value your ability to work independent...  Positive
# 47  I wanted to congratulate you on doing such an ...  Positive
# 48  Cassandra, you have consistently produced grea...  Negative
# 49  It's incredible to see how far you've come fro...  Positive
# 50  Patrick, I noticed you have come into work lat...  Negative
# 51  Heath, I loved seeing your passion for reachin...  Negative
# 52  Katrina, I appreciate your enthusiasm for coll...  Positive
#
#                                      Sentiment_BERT Sentiment_Label_BERT  \
# 0   [{'label': 'NEU', 'score': 0.7832766175270081}]                  NEU
# 1   [{'label': 'POS', 'score': 0.8706808686256409}]                  POS
# 2   [{'label': 'POS', 'score': 0.9895287156105042}]                  POS
# 3    [{'label': 'POS', 'score': 0.990766167640686}]                  POS
# 4   [{'label': 'POS', 'score': 0.5218806266784668}]                  POS
# 5    [{'label': 'POS', 'score': 0.992424726486206}]                  POS
# 6   [{'label': 'POS', 'score': 0.9926396608352661}]                  POS
# 7   [{'label': 'NEU', 'score': 0.7238913774490356}]                  NEU
# 8    [{'label': 'NEU', 'score': 0.894446849822998}]                  NEU
# 9    [{'label': 'POS', 'score': 0.643831729888916}]                  POS
# 10  [{'label': 'NEG', 'score': 0.5578166842460632}]                  NEG
# 11  [{'label': 'NEU', 'score': 0.8998710513114929}]                  NEU
# 12  [{'label': 'POS', 'score': 0.8490467071533203}]                  POS
# 13  [{'label': 'NEU', 'score': 0.8428518772125244}]                  NEU
# 14  [{'label': 'POS', 'score': 0.9262285828590393}]                  POS
# 15   [{'label': 'POS', 'score': 0.989471971988678}]                  POS
# 16  [{'label': 'POS', 'score': 0.9920229911804199}]                  POS
# 17  [{'label': 'POS', 'score': 0.8268365263938904}]                  POS
# 18  [{'label': 'POS', 'score': 0.8873103260993958}]                  POS
# 19  [{'label': 'NEU', 'score': 0.8385621905326843}]                  NEU
# 20  [{'label': 'NEG', 'score': 0.8178383708000183}]                  NEG
# 21  [{'label': 'POS', 'score': 0.8195364475250244}]                  POS
# 22  [{'label': 'POS', 'score': 0.9903046488761902}]                  POS
# 23  [{'label': 'POS', 'score': 0.9303642511367798}]                  POS
# 24  [{'label': 'POS', 'score': 0.9916355609893799}]                  POS
# 25  [{'label': 'POS', 'score': 0.8473824858665466}]                  POS
# 26  [{'label': 'POS', 'score': 0.9599489569664001}]                  POS
# 27  [{'label': 'POS', 'score': 0.9920806288719177}]                  POS
# 28  [{'label': 'POS', 'score': 0.9567974805831909}]                  POS
# 29  [{'label': 'POS', 'score': 0.9910680651664734}]                  POS
# 30  [{'label': 'NEU', 'score': 0.7682642340660095}]                  NEU
# 31  [{'label': 'NEU', 'score': 0.6878769993782043}]                  NEU
# 32  [{'label': 'POS', 'score': 0.9894165396690369}]                  POS
# 33  [{'label': 'NEG', 'score': 0.9627170562744141}]                  NEG
# 34  [{'label': 'POS', 'score': 0.9905153512954712}]                  POS
# 35  [{'label': 'POS', 'score': 0.9916315674781799}]                  POS
# 36  [{'label': 'POS', 'score': 0.9926139116287231}]                  POS
# 37  [{'label': 'POS', 'score': 0.7888559103012085}]                  POS
# 38  [{'label': 'POS', 'score': 0.9929960370063782}]                  POS
# 39  [{'label': 'POS', 'score': 0.9924665093421936}]                  POS
# 40  [{'label': 'POS', 'score': 0.4527025818824768}]                  POS
# 41  [{'label': 'POS', 'score': 0.9467945098876953}]                  POS
# 42  [{'label': 'POS', 'score': 0.9927736520767212}]                  POS
# 43  [{'label': 'POS', 'score': 0.9886244535446167}]                  POS
# 44  [{'label': 'NEG', 'score': 0.5347089171409607}]                  NEG
# 45   [{'label': 'POS', 'score': 0.987270712852478}]                  POS
# 46  [{'label': 'POS', 'score': 0.9317291378974915}]                  POS
# 47  [{'label': 'POS', 'score': 0.9914699196815491}]                  POS
# 48  [{'label': 'POS', 'score': 0.8688120245933533}]                  POS
# 49  [{'label': 'POS', 'score': 0.9924125075340271}]                  POS
# 50  [{'label': 'NEU', 'score': 0.5260989665985107}]                  NEU
# 51  [{'label': 'POS', 'score': 0.9880756139755249}]                  POS
# 52  [{'label': 'POS', 'score': 0.9581375122070312}]                  POS
#
#    Label_BERT                                  Sentiment_ROBERTA  \
# 0     Neutral  [{'label': 'LABEL_1', 'score': 0.4449909329414...
# 1    Positive  [{'label': 'LABEL_2', 'score': 0.8078871369361...
# 2    Positive  [{'label': 'LABEL_2', 'score': 0.9781804084777...
# 3    Positive  [{'label': 'LABEL_2', 'score': 0.9867540001869...
# 4    Positive  [{'label': 'LABEL_2', 'score': 0.8090545535087...
# 5    Positive  [{'label': 'LABEL_2', 'score': 0.9875206947326...
# 6    Positive  [{'label': 'LABEL_2', 'score': 0.9924782514572...
# 7     Neutral  [{'label': 'LABEL_1', 'score': 0.6282107830047...
# 8     Neutral  [{'label': 'LABEL_1', 'score': 0.8330121636390...
# 9    Positive  [{'label': 'LABEL_1', 'score': 0.5577819943428...
# 10   Negative  [{'label': 'LABEL_1', 'score': 0.5402156710624...
# 11    Neutral  [{'label': 'LABEL_1', 'score': 0.6723153591156...
# 12   Positive  [{'label': 'LABEL_2', 'score': 0.6546157002449...
# 13    Neutral  [{'label': 'LABEL_1', 'score': 0.6335223913192...
# 14   Positive  [{'label': 'LABEL_2', 'score': 0.8918081521987...
# 15   Positive  [{'label': 'LABEL_2', 'score': 0.9608932733535...
# 16   Positive  [{'label': 'LABEL_2', 'score': 0.94724440574646}]
# 17   Positive  [{'label': 'LABEL_1', 'score': 0.4023545086383...
# 18   Positive  [{'label': 'LABEL_2', 'score': 0.6904166340827...
# 19    Neutral  [{'label': 'LABEL_1', 'score': 0.5679895281791...
# 20   Negative  [{'label': 'LABEL_0', 'score': 0.5842345356941...
# 21   Positive  [{'label': 'LABEL_2', 'score': 0.6277636885643...
# 22   Positive  [{'label': 'LABEL_2', 'score': 0.9805015921592...
# 23   Positive  [{'label': 'LABEL_1', 'score': 0.4577948451042...
# 24   Positive  [{'label': 'LABEL_2', 'score': 0.9836588501930...
# 25   Positive  [{'label': 'LABEL_1', 'score': 0.5819616913795...
# 26   Positive  [{'label': 'LABEL_2', 'score': 0.6239237189292...
# 27   Positive  [{'label': 'LABEL_2', 'score': 0.9843794703483...
# 28   Positive  [{'label': 'LABEL_2', 'score': 0.6163787245750...
# 29   Positive  [{'label': 'LABEL_2', 'score': 0.9453541040420...
# 30    Neutral  [{'label': 'LABEL_1', 'score': 0.6877532601356...
# 31    Neutral  [{'label': 'LABEL_1', 'score': 0.5963156819343...
# 32   Positive  [{'label': 'LABEL_2', 'score': 0.9560742378234...
# 33   Negative  [{'label': 'LABEL_0', 'score': 0.8297402858734...
# 34   Positive  [{'label': 'LABEL_2', 'score': 0.9741307497024...
# 35   Positive  [{'label': 'LABEL_2', 'score': 0.9848963022232...
# 36   Positive  [{'label': 'LABEL_2', 'score': 0.9868506789207...
# 37   Positive  [{'label': 'LABEL_2', 'score': 0.7865098118782...
# 38   Positive  [{'label': 'LABEL_2', 'score': 0.9929976463317...
# 39   Positive  [{'label': 'LABEL_2', 'score': 0.9863968491554...
# 40   Positive  [{'label': 'LABEL_2', 'score': 0.5351472496986...
# 41   Positive  [{'label': 'LABEL_2', 'score': 0.8980029225349...
# 42   Positive  [{'label': 'LABEL_2', 'score': 0.9887780547142...
# 43   Positive  [{'label': 'LABEL_2', 'score': 0.9641283750534...
# 44   Negative  [{'label': 'LABEL_0', 'score': 0.6414420604705...
# 45   Positive  [{'label': 'LABEL_2', 'score': 0.9636879563331...
# 46   Positive  [{'label': 'LABEL_2', 'score': 0.5278257131576...
# 47   Positive      [{'label': 'LABEL_2', 'score': 0.9716796875}]
# 48   Positive  [{'label': 'LABEL_2', 'score': 0.5660250782966...
# 49   Positive  [{'label': 'LABEL_2', 'score': 0.9883816838264...
# 50    Neutral  [{'label': 'LABEL_0', 'score': 0.5567397475242...
# 51   Positive  [{'label': 'LABEL_2', 'score': 0.8896149396896...
# 52   Positive  [{'label': 'LABEL_2', 'score': 0.7829574942588...
#
#    Sentiment_Label_ROBERTA Label_ROBERTA  \
# 0                  LABEL_1       Neutral
# 1                  LABEL_2      Positive
# 2                  LABEL_2      Positive
# 3                  LABEL_2      Positive
# 4                  LABEL_2      Positive
# 5                  LABEL_2      Positive
# 6                  LABEL_2      Positive
# 7                  LABEL_1       Neutral
# 8                  LABEL_1       Neutral
# 9                  LABEL_1       Neutral
# 10                 LABEL_1       Neutral
# 11                 LABEL_1       Neutral
# 12                 LABEL_2      Positive
# 13                 LABEL_1       Neutral
# 14                 LABEL_2      Positive
# 15                 LABEL_2      Positive
# 16                 LABEL_2      Positive
# 17                 LABEL_1       Neutral
# 18                 LABEL_2      Positive
# 19                 LABEL_1       Neutral
# 20                 LABEL_0      Negative
# 21                 LABEL_2      Positive
# 22                 LABEL_2      Positive
# 23                 LABEL_1       Neutral
# 24                 LABEL_2      Positive
# 25                 LABEL_1       Neutral
# 26                 LABEL_2      Positive
# 27                 LABEL_2      Positive
# 28                 LABEL_2      Positive
# 29                 LABEL_2      Positive
# 30                 LABEL_1       Neutral
# 31                 LABEL_1       Neutral
# 32                 LABEL_2      Positive
# 33                 LABEL_0      Negative
# 34                 LABEL_2      Positive
# 35                 LABEL_2      Positive
# 36                 LABEL_2      Positive
# 37                 LABEL_2      Positive
# 38                 LABEL_2      Positive
# 39                 LABEL_2      Positive
# 40                 LABEL_2      Positive
# 41                 LABEL_2      Positive
# 42                 LABEL_2      Positive
# 43                 LABEL_2      Positive
# 44                 LABEL_0      Negative
# 45                 LABEL_2      Positive
# 46                 LABEL_2      Positive
# 47                 LABEL_2      Positive
# 48                 LABEL_2      Positive
# 49                 LABEL_2      Positive
# 50                 LABEL_0      Negative
# 51                 LABEL_2      Positive
# 52                 LABEL_2      Positive
#
#                                            Feedback_2
# 0   want talk work last project delay impacted tea...
# 1   want talk priorities noticed well projects 2 3...
# 2   reaching goal name goal big accomplishment rem...
# 3   one impactful moments handled project x showed...
# 4   clear youre excited project sometimes get exci...
# 5   want congratulate performance name specific ac...
# 6   really appreciated kept date x project week he...
# 7   ive noticed seem less engaged lately important...
# 8   im curious project issues come best know soon ...
# 9   know name project really important youre excit...
# 10  cant help notice third deadline thats caught m...
# 11  sensed tension planning meeting yesterday want...
# 12  itd great see take fewer projects narrow focus...
# 13  ive noticed recently take long time reply impo...
# 14  work x z solid valuable accomplishments quarte...
# 15  wanted talk said meeting know get along well t...
# 16  truly impressed managed meet every goal set ho...
# 17  know ive always appreciated grasp larger visio...
# 18  id love keep bigpicture vision working little ...
# 19  weve adapting new reality differently ive noti...
# 20  hey noticed werent last morning meetings im co...
# 21  fantastic job collaborating team last week wor...
# 22  say excellent point contact team know speak en...
# 23  itd great see tap resourcefulness apply proble...
# 24  input todays meeting gamechanger project see i...
# 25  wanted check see things going dont seem quite ...
# 26  im glad taking time checkin feel like havent h...
# 27  really appreciated efforts keep every team mem...
# 28  appreciate input issue helpful team share addr...
# 29  appreciate fact covering tims work since went ...
# 30  know lot rumors flying around x know youre con...
# 31  hey wanted checkin see felt work week samika m...
# 32  commendable acted mediator recent conflict inv...
# 33  morning left team meeting early could tell fru...
# 34  ive noticed youve taking increasingly challeng...
# 35  congratulations finishing challenging project ...
# 36  ive seen grow tremendously three years youve w...
# 37  helen always appreciate productive reliable no...
# 38  weve seen incredible growth progress since too...
# 39  received positive verbal feedback one clients ...
# 40  joe impressive time management skills complete...
# 41  sandra passion talent graphic design keeps tea...
# 42  according client putting extra efforts meet pr...
# 43  thank recent overtime youve worked cover peopl...
# 44  bobby wanted check behaviors seen last weeks b...
# 45  admire tact handled conflict another team memb...
# 46  jade value ability work independently maintain...
# 47  wanted congratulate amazing job mastering skil...
# 48  cassandra consistently produced great work tea...
# 49  incredible see far youve come shy intern takin...
# 50  patrick noticed come work later usual missed b...
# 51  heath loved seeing passion reaching goals tues...
# 52  katrina appreciate enthusiasm collaboration as...

# %%
from afinn import Afinn
afinn = Afinn()

#apply afinn score and polarity
df['sentiment_score'] = df['Feedback_2'].apply(lambda x: afinn.score(x))

scores = df['sentiment_score']
sentiment = ['Positive' if score >= 0
                          else 'Negative' 
                                  for score in scores]
df['Label_AFINN'] = sentiment

# %%
df.head()
# Out:
#                                             Feedback     Label  \
# 0  I want to talk to you about your work on this ...  Negative
# 1  I want to talk to you about your priorities. I...  Positive
# 2  Reaching your goal of [name the goal] is a big...  Positive
# 3  One of your most impactful moments was how you...  Positive
# 4  It’s clear you’re excited about the project. B...  Negative
#
#                                     Sentiment_BERT Sentiment_Label_BERT  \
# 0  [{'label': 'NEU', 'score': 0.7832766175270081}]                  NEU
# 1  [{'label': 'POS', 'score': 0.8706808686256409}]                  POS
# 2  [{'label': 'POS', 'score': 0.9895287156105042}]                  POS
# 3   [{'label': 'POS', 'score': 0.990766167640686}]                  POS
# 4  [{'label': 'POS', 'score': 0.5218806266784668}]                  POS
#
#   Label_BERT                                  Sentiment_ROBERTA  \
# 0    Neutral  [{'label': 'LABEL_1', 'score': 0.4449909329414...
# 1   Positive  [{'label': 'LABEL_2', 'score': 0.8078871369361...
# 2   Positive  [{'label': 'LABEL_2', 'score': 0.9781804084777...
# 3   Positive  [{'label': 'LABEL_2', 'score': 0.9867540001869...
# 4   Positive  [{'label': 'LABEL_2', 'score': 0.8090545535087...
#
#   Sentiment_Label_ROBERTA Label_ROBERTA  \
# 0                 LABEL_1       Neutral
# 1                 LABEL_2      Positive
# 2                 LABEL_2      Positive
# 3                 LABEL_2      Positive
# 4                 LABEL_2      Positive
#
#                                           Feedback_2  sentiment_score  \
# 0  want talk work last project delay impacted tea...              4.0
# 1  want talk priorities noticed well projects 2 3...              8.0
# 2  reaching goal name goal big accomplishment rem...              7.0
# 3  one impactful moments handled project x showed...              7.0
# 4  clear youre excited project sometimes get exci...              6.0
#
#   Label_AFINN
# 0    Positive
# 1    Positive
# 2    Positive
# 3    Positive
# 4    Positive

# %%
df.to_excel(r'C:\Users\USUARIO\Documents\Maestria\Prompt Engineering\Comparacion Modelos.xlsx', index=False)

# %% [markdown]
# ### Determinación mejor modelo

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
print('AFINN', classification_report(df['Label'],df['Label_AFINN']))
# Out:
# AFINN               precision    recall  f1-score   support
#
#     Negative       0.80      0.27      0.40        15
#     Positive       0.77      0.97      0.86        38
#
#     accuracy                           0.77        53
#    macro avg       0.79      0.62      0.63        53
# weighted avg       0.78      0.77      0.73        53

# %%
print("AFIN\n",confusion_matrix(df['Label'],df['Label_AFINN']))
# Out:
# AFIN
#  [[ 4 11]
#  [ 1 37]]

# %%
print('ROBERTA', classification_report(df['Label'],df['Label_ROBERTA']))
# Out:
# ROBERTA               precision    recall  f1-score   support
#
#     Negative       1.00      0.27      0.42        15
#      Neutral       0.00      0.00      0.00         0
#     Positive       0.89      0.84      0.86        38
#
#     accuracy                           0.68        53
#    macro avg       0.63      0.37      0.43        53
# weighted avg       0.92      0.68      0.74        53
# C:\Users\USUARIO\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USUARIO\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USUARIO\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("ROBERTA\n",confusion_matrix(df['Label'],df['Label_ROBERTA']))
# Out:
# ROBERTA
#  [[ 4  7  4]
#  [ 0  0  0]
#  [ 0  6 32]]

# %%
print('BERT', classification_report(df['Label'],df['Label_BERT']))
# Out:
# BERT               precision    recall  f1-score   support
#
#     Negative       1.00      0.27      0.42        15
#      Neutral       0.00      0.00      0.00         0
#     Positive       0.85      0.89      0.87        38
#
#     accuracy                           0.72        53
#    macro avg       0.62      0.39      0.43        53
# weighted avg       0.89      0.72      0.74        53
# C:\Users\USUARIO\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USUARIO\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USUARIO\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("BERT\n",confusion_matrix(df['Label'],df['Label_BERT']))
# Out:
# BERT
#  [[ 4  5  6]
#  [ 0  0  0]
#  [ 0  4 34]]
